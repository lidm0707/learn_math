# %% [markdown]
# # Exam 2: Calculus & Probability
#
# ## Instructions
# - **15 questions**, each worth 1 point
# - Write code where it says `# YOUR CODE HERE`
# - Run each cell to auto-check
# - **No peeking at solutions!**
#
# ## Scoring
# - 13-15: A (Excellent)
# - 10-12: B (Good)
# - 7-9: C (Needs work)
# - Below 7: F (Re-study required)

# %%
import numpy as np
SCORE = 0
TOTAL = 15

# %% [markdown]
# ## Section A: Calculus (Questions 1-8)

# %% [markdown]
# ### Q1 (1 point): The derivative of `f(x) = x^3` is `f'(x) = 3x^2`. What is `f'(2)`?

# %%
answer = None
# YOUR CODE HERE


try:
    assert answer is not None
    assert answer == 12, f"Expected 12, got {answer}"
    SCORE += 1
    print("Q1: CORRECT")
except AssertionError as e:
    print(f"Q1: WRONG - {e}")

# %% [markdown]
# ### Q2 (1 point): Compute the numerical derivative of `f(x) = x^2` at `x = 3` using the formula `(f(x+h) - f(x-h)) / (2*h)` with `h = 0.0001`. Store in `deriv`.

# %%
deriv = None
def f(x):
    return x**2
x = 3.0
h = 0.0001
# YOUR CODE HERE


try:
    assert deriv is not None
    assert np.isclose(deriv, 6.0, atol=0.01), f"Expected ~6.0, got {deriv}"
    SCORE += 1
    print("Q2: CORRECT")
except AssertionError as e:
    print(f"Q2: WRONG - {e}")

# %% [markdown]
# ### Q3 (1 point): At the minimum of `f(x) = (x-5)^2`, what is the derivative?
#
# Set `answer` to: 1. Positive, 2. Zero, 3. Negative

# %%
answer = None
# YOUR CODE HERE


try:
    assert answer is not None
    assert answer == 2, f"Expected 2 (zero), got {answer}"
    SCORE += 1
    print("Q3: CORRECT")
except AssertionError as e:
    print(f"Q3: WRONG - {e}")

# %% [markdown]
# ### Q4 (1 point): Perform one gradient descent step on `f(x) = x^2` starting at `x=4` with `lr=0.1`. Store the new x in `x_new`.

# %%
x_new = None
x = 4.0
lr = 0.1
# YOUR CODE HERE


try:
    assert x_new is not None
    assert np.isclose(x_new, 3.2), f"Expected 3.2, got {x_new}"
    SCORE += 1
    print("Q4: CORRECT")
except AssertionError as e:
    print(f"Q4: WRONG - {e}")

# %% [markdown]
# ### Q5 (1 point): The gradient of `f(x,y) = x^2 + y^2` at point `(3,4)` is `[6, 8]`. Which direction should you move to DESCEND?
#
# Set `answer` to: 1. `[6, 8]` (the gradient), 2. `[-6, -8]` (opposite), 3. `[0, 0]`

# %%
answer = None
# YOUR CODE HERE


try:
    assert answer is not None
    assert answer == 2, f"Expected 2 (opposite to gradient), got {answer}"
    SCORE += 1
    print("Q5: CORRECT")
except AssertionError as e:
    print(f"Q5: WRONG - {e}")

# %% [markdown]
# ### Q6 (1 point): If `g(x) = 3x + 1` and `f(u) = u^2`, then `f(g(x))` = `(3x+1)^2`. Using the chain rule, what is `d/dx[f(g(x))]` at `x=1`?

# %%
answer = None
# YOUR CODE HERE


try:
    assert answer is not None
    assert answer == 24, f"Expected 24, got {answer}"
    SCORE += 1
    print("Q6: CORRECT")
except AssertionError as e:
    print(f"Q6: WRONG - {e}")

# %% [markdown]
# ### Q7 (1 point): If `learning_rate` is too large, gradient descent will:
#
# Set `answer` to: 1. Converge faster, 2. Oscillate or diverge, 3. Stay the same

# %%
answer = None
# YOUR CODE HERE


try:
    assert answer is not None
    assert answer == 2, f"Expected 2 (oscillate/diverge), got {answer}"
    SCORE += 1
    print("Q7: CORRECT")
except AssertionError as e:
    print(f"Q7: WRONG - {e}")

# %% [markdown]
# ### Q8 (1 point): In a neural network, backpropagation is just the ______ rule applied repeatedly.
#
# Set `answer` to: 1. Product, 2. Chain, 3. Power

# %%
answer = None
# YOUR CODE HERE


try:
    assert answer is not None
    assert answer == 2, f"Expected 2 (chain rule), got {answer}"
    SCORE += 1
    print("Q8: CORRECT")
except AssertionError as e:
    print(f"Q8: WRONG - {e}")

# %% [markdown]
# ## Section B: Probability & Statistics (Questions 9-15)

# %% [markdown]
# ### Q9 (1 point): Compute the mean of `[10, 20, 30, 40, 50]`, store in `mean_val`

# %%
mean_val = None
data = np.array([10, 20, 30, 40, 50])
# YOUR CODE HERE


try:
    assert mean_val is not None
    assert np.isclose(mean_val, 30.0), f"Expected 30.0, got {mean_val}"
    SCORE += 1
    print("Q9: CORRECT")
except AssertionError as e:
    print(f"Q9: WRONG - {e}")

# %% [markdown]
# ### Q10 (1 point): Compute the standard deviation of `[10, 20, 30, 40, 50]`, store in `std_val`

# %%
std_val = None
data = np.array([10, 20, 30, 40, 50])
# YOUR CODE HERE


try:
    assert std_val is not None
    assert np.isclose(std_val, 14.142, atol=0.1), f"Expected ~14.14, got {std_val}"
    SCORE += 1
    print("Q10: CORRECT")
except AssertionError as e:
    print(f"Q10: WRONG - {e}")

# %% [markdown]
# ### Q11 (1 point): Compute correlation between `x = [1,2,3,4,5]` and `y = [2,4,6,8,10]`, store in `corr`

# %%
corr = None
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 6, 8, 10])
# YOUR CODE HERE


try:
    assert corr is not None
    assert np.isclose(corr, 1.0), f"Expected 1.0, got {corr}"
    SCORE += 1
    print("Q11: CORRECT")
except AssertionError as e:
    print(f"Q11: WRONG - {e}")

# %% [markdown]
# ### Q12 (1 point): In the normal distribution, approximately what % of data falls within ±1 standard deviation?
#
# Set `answer` to: 1. 50%, 2. 68%, 3. 95%

# %%
answer = None
# YOUR CODE HERE


try:
    assert answer is not None
    assert answer == 2, f"Expected 2 (68%), got {answer}"
    SCORE += 1
    print("Q12: CORRECT")
except AssertionError as e:
    print(f"Q12: WRONG - {e}")

# %% [markdown]
# ### Q13 (1 point): The Central Limit Theorem says that sample averages tend toward a ______ distribution.
#
# Set `answer` to: 1. Uniform, 2. Normal (bell curve), 3. Exponential

# %%
answer = None
# YOUR CODE HERE


try:
    assert answer is not None
    assert answer == 2, f"Expected 2 (normal), got {answer}"
    SCORE += 1
    print("Q13: CORRECT")
except AssertionError as e:
    print(f"Q13: WRONG - {e}")

# %% [markdown]
# ### Q14 (1 point): A medical test is 90% accurate for sick people and 5% false positive for healthy. If 1% of people are sick and you test positive, is your chance of being sick closer to:
#
# Set `answer` to: 1. ~90%, 2. ~15%, 3. ~50%

# %%
answer = None
# YOUR CODE HERE


try:
    assert answer is not None
    assert answer == 2, f"Expected 2 (~15%, Bayes' theorem), got {answer}"
    SCORE += 1
    print("Q14: CORRECT")
except AssertionError as e:
    print(f"Q14: WRONG - {e}")

# %% [markdown]
# ### Q15 (1 point): Which is more robust to outliers: mean or median?
#
# Set `answer` to: 1. Mean, 2. Median

# %%
answer = None
# YOUR CODE HERE


try:
    assert answer is not None
    assert answer == 2, f"Expected 2 (median), got {answer}"
    SCORE += 1
    print("Q15: CORRECT")
except AssertionError as e:
    print(f"Q15: WRONG - {e}")

# %% [markdown]
# ---
# ## Score Report

# %%
print("=" * 40)
print(f"  CALCULUS & PROBABILITY EXAM")
print(f"  Score: {SCORE} / {TOTAL}")
print(f"  Percentage: {SCORE/TOTAL*100:.0f}%")
print("=" * 40)
if SCORE >= 13:
    print("  GRADE: A - Excellent!")
elif SCORE >= 10:
    print("  GRADE: B - Good")
elif SCORE >= 7:
    print("  GRADE: C - Needs work")
else:
    print("  GRADE: F - Re-study required")
print("=" * 40)

# %% [markdown]
# ---
# ## Solutions
#
# **Q1:** `answer = 12` (f'(x)=3x^2, f'(2)=3*4=12)
#
# **Q2:** `deriv = (f(x+h) - f(x-h)) / (2*h)`
#
# **Q3:** `answer = 2` (derivative is zero at minimum)
#
# **Q4:** `x_new = x - lr * 2*x` = 4 - 0.1*8 = 3.2
#
# **Q5:** `answer = 2` (opposite to gradient to descend)
#
# **Q6:** `answer = 24` (chain rule: f'(g(1))*g'(1) = 2*4*3 = 24)
#
# **Q7:** `answer = 2` (too large lr → oscillate/diverge)
#
# **Q8:** `answer = 2` (backprop = chain rule)
#
# **Q9:** `mean_val = np.mean(data)`
#
# **Q10:** `std_val = np.std(data)`
#
# **Q11:** `corr = np.corrcoef(x, y)[0, 1]`
#
# **Q12:** `answer = 2` (68%)
#
# **Q13:** `answer = 2` (Normal)
#
# **Q14:** `answer = 2` (~15% by Bayes' theorem)
#
# **Q15:** `answer = 2` (Median)
