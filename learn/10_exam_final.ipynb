# %% [markdown]
# # Final Exam: Math for Machine Learning (Comprehensive)
#
# ## Instructions
# - **20 questions** covering ALL topics (Linear Algebra, Calculus, Probability, Optimization)
# - Each worth 1 point
# - Mix of coding and concept questions
# - Run each cell to auto-check
# - **Do NOT look at solutions until finished!**
# - Recommended time: 45-60 minutes
#
# ## Scoring
# - 18-20: A (Mastered!)
# - 15-17: B (Strong understanding)
# - 12-14: C (Acceptable, review gaps)
# - 10-11: D (Below passing)
# - Below 10: F (Re-study required)

# %%
import numpy as np
SCORE = 0
TOTAL = 20
SECTIONS = {"Linear Algebra": 0, "Calculus": 0, "Probability": 0, "Optimization": 0, "Applied": 0}

# %% [markdown]
# ## Part 1: Linear Algebra (Q1-5)

# %% [markdown]
# ### Q1 (1pt): Create a 3x3 identity matrix, store in `I3`

# %%
I3 = None
# YOUR CODE HERE

try:
    assert I3 is not None and np.allclose(I3, np.eye(3))
    SCORE += 1; SECTIONS["Linear Algebra"] += 1; print("Q1: CORRECT")
except: print("Q1: WRONG")

# %% [markdown]
# ### Q2 (1pt): Compute `A @ B` where `A=[[1,0],[0,2]]`, `B=[[3],[4]]`. Store in `result`.

# %%
result = None
A = np.array([[1,0],[0,2]])
B = np.array([[3],[4]])
# YOUR CODE HERE

try:
    assert result is not None and np.allclose(result, [[3],[8]])
    SCORE += 1; SECTIONS["Linear Algebra"] += 1; print("Q2: CORRECT")
except: print("Q2: WRONG")

# %% [markdown]
# ### Q3 (1pt): What is the determinant of `[[2,0],[0,3]]`? Store in `det_val`.

# %%
det_val = None
# YOUR CODE HERE

try:
    assert det_val is not None and np.isclose(det_val, 6.0)
    SCORE += 1; SECTIONS["Linear Algebra"] += 1; print("Q3: CORRECT")
except: print("Q3: WRONG")

# %% [markdown]
# ### Q4 (1pt): Solve `3x + 2y = 12`, `x + y = 5`. Store `[x,y]` in `sol`.

# %%
sol = None
# YOUR CODE HERE

try:
    assert sol is not None and np.isclose(sol[0], 2.0) and np.isclose(sol[1], 3.0)
    SCORE += 1; SECTIONS["Linear Algebra"] += 1; print("Q4: CORRECT")
except: print("Q4: WRONG")

# %% [markdown]
# ### Q5 (1pt): The eigenvalues of `[[5,0],[0,3]]` are 5 and 3. This means the transformation:
# 1. Stretches one axis by 5, other by 3
# 2. Rotates by 5 degrees
# 3. Shears by 3 units

# %%
answer = None
# YOUR CODE HERE

try:
    assert answer == 1
    SCORE += 1; SECTIONS["Linear Algebra"] += 1; print("Q5: CORRECT")
except: print("Q5: WRONG")

# %% [markdown]
# ## Part 2: Calculus (Q6-9)

# %% [markdown]
# ### Q6 (1pt): The derivative of `f(x) = 5x^2` at `x=3` is?

# %%
answer = None
# YOUR CODE HERE

try:
    assert answer == 30
    SCORE += 1; SECTIONS["Calculus"] += 1; print("Q6: CORRECT")
except: print("Q6: WRONG")

# %% [markdown]
# ### Q7 (1pt): Starting at `x=5` on `f(x)=x^2`, with `lr=0.1`, one GD step gives `x_new = ?`

# %%
answer = None
# YOUR CODE HERE

try:
    assert answer is not None and np.isclose(answer, 4.0)
    SCORE += 1; SECTIONS["Calculus"] += 1; print("Q7: CORRECT")
except: print("Q7: WRONG")

# %% [markdown]
# ### Q8 (1pt): Backpropagation in neural networks uses which rule?
# 1. Power rule  2. Chain rule  3. Product rule

# %%
answer = None
# YOUR CODE HERE

try:
    assert answer == 2
    SCORE += 1; SECTIONS["Calculus"] += 1; print("Q8: CORRECT")
except: print("Q8: WRONG")

# %% [markdown]
# ### Q9 (1pt): The gradient of `f(x,y) = x^2 + y^2` at `(1,2)` is `[2, 4]`. To descend, you move:
# 1. In direction `[2, 4]`  2. In direction `[-2, -4]`  3. No movement

# %%
answer = None
# YOUR CODE HERE

try:
    assert answer == 2
    SCORE += 1; SECTIONS["Calculus"] += 1; print("Q9: CORRECT")
except: print("Q9: WRONG")

# %% [markdown]
# ## Part 3: Probability & Statistics (Q10-13)

# %% [markdown]
# ### Q10 (1pt): Compute the variance of `[2, 4, 6, 8, 10]`, store in `var_val`

# %%
var_val = None
data = np.array([2, 4, 6, 8, 10])
# YOUR CODE HERE

try:
    assert var_val is not None and np.isclose(var_val, 8.0)
    SCORE += 1; SECTIONS["Probability"] += 1; print("Q10: CORRECT")
except: print("Q10: WRONG")

# %% [markdown]
# ### Q11 (1pt): If two variables have correlation `r = -0.95`, they:
# 1. Have no relationship  2. Move strongly in opposite directions  3. Move strongly together

# %%
answer = None
# YOUR CODE HERE

try:
    assert answer == 2
    SCORE += 1; SECTIONS["Probability"] += 1; print("Q11: CORRECT")
except: print("Q11: WRONG")

# %% [markdown]
# ### Q12 (1pt): The Central Limit Theorem says averages of samples approach a:
# 1. Uniform distribution  2. Normal distribution  3. Exponential distribution

# %%
answer = None
# YOUR CODE HERE

try:
    assert answer == 2
    SCORE += 1; SECTIONS["Probability"] += 1; print("Q12: CORRECT")
except: print("Q12: WRONG")

# %% [markdown]
# ### Q13 (1pt): Bayes' Theorem: `P(A|B) = P(B|A) * P(A) / P(B)`. If P(A)=0.01, P(B|A)=0.9, P(B|not A)=0.05, compute P(A|B). Store in `p_ab`.

# %%
p_ab = None
# YOUR CODE HERE

try:
    assert p_ab is not None and np.isclose(p_ab, 0.1538, atol=0.01)
    SCORE += 1; SECTIONS["Probability"] += 1; print("Q13: CORRECT")
except: print("Q13: WRONG")

# %% [markdown]
# ## Part 4: Optimization (Q14-16)

# %% [markdown]
# ### Q14 (1pt): MSE loss for predictions `[3, 5, 7]` vs actual `[2, 5, 8]` is? Store in `mse`.

# %%
mse = None
pred = np.array([3, 5, 7])
actual = np.array([2, 5, 8])
# YOUR CODE HERE

try:
    assert mse is not None and np.isclose(mse, 2/3, atol=0.01)
    SCORE += 1; SECTIONS["Optimization"] += 1; print("Q14: CORRECT")
except: print("Q14: WRONG")

# %% [markdown]
# ### Q15 (1pt): In SGD, what does the 'S' stand for?
# 1. Simple  2. Stochastic  3. Standard

# %%
answer = None
# YOUR CODE HERE

try:
    assert answer == 2
    SCORE += 1; SECTIONS["Optimization"] += 1; print("Q15: CORRECT")
except: print("Q15: WRONG")

# %% [markdown]
# ### Q16 (1pt): Linear regression loss landscape is:
# 1. Convex (one global minimum)  2. Non-convex (many local minima)  3. Flat

# %%
answer = None
# YOUR CODE HERE

try:
    assert answer == 1
    SCORE += 1; SECTIONS["Optimization"] += 1; print("Q16: CORRECT")
except: print("Q16: WRONG")

# %% [markdown]
# ## Part 5: Applied & Integration (Q17-20)

# %% [markdown]
# ### Q17 (1pt): Compute cosine similarity between `[1,0]` and `[0,1]`. Store in `cos_sim`.

# %%
cos_sim = None
a = np.array([1, 0])
b = np.array([0, 1])
# YOUR CODE HERE

try:
    assert cos_sim is not None and np.isclose(cos_sim, 0.0)
    SCORE += 1; SECTIONS["Applied"] += 1; print("Q17: CORRECT")
except: print("Q17: WRONG")

# %% [markdown]
# ### Q18 (1pt): PCA uses eigenvalues of which matrix?
# 1. Identity matrix  2. Covariance matrix  3. Inverse matrix

# %%
answer = None
# YOUR CODE HERE

try:
    assert answer == 2
    SCORE += 1; SECTIONS["Applied"] += 1; print("Q18: CORRECT")
except: print("Q18: WRONG")

# %% [markdown]
# ### Q19 (1pt): The normal equation for least squares is: `w = (X^T X)^(-1) X^T y`. This is:
# 1. Pure calculus  2. Pure linear algebra  3. Pure probability

# %%
answer = None
# YOUR CODE HERE

try:
    assert answer == 2
    SCORE += 1; SECTIONS["Applied"] += 1; print("Q19: CORRECT")
except: print("Q19: WRONG")

# %% [markdown]
# ### Q20 (1pt): Complete the ML training loop. Fill in the gradient update:
# ```python
# weights -= learning_rate * ????
# ```
#
# 1. `loss`  2. `gradient`  3. `predictions`

# %%
answer = None
# YOUR CODE HERE

try:
    assert answer == 2
    SCORE += 1; SECTIONS["Applied"] += 1; print("Q20: CORRECT")
except: print("Q20: WRONG")

# %% [markdown]
# ---
# ## Final Score Report

# %%
print("=" * 50)
print("   FINAL EXAM: MATH FOR MACHINE LEARNING")
print("=" * 50)
print(f"   Total Score: {SCORE} / {TOTAL} ({SCORE/TOTAL*100:.0f}%)")
print("-" * 50)
print("   Breakdown by Section:")
for section, max_q in [("Linear Algebra", 5), ("Calculus", 4), ("Probability", 4), ("Optimization", 3), ("Applied", 4)]:
    s = SECTIONS[section]
    bar = "█" * s + "░" * (max_q - s)
    print(f"   {section:>18}: [{bar}] {s}/{max_q}")
print("-" * 50)
if SCORE >= 18:
    grade = "A"
elif SCORE >= 15:
    grade = "B"
elif SCORE >= 12:
    grade = "C"
elif SCORE >= 10:
    grade = "D"
else:
    grade = "F"
print(f"   GRADE: {grade}")
print("=" * 50)

weak = [s for s, m in [("Linear Algebra",5),("Calculus",4),("Probability",4),("Optimization",3),("Applied",4)] if SECTIONS[s] < m * 0.6]
if weak:
    print(f"\n   Weak areas: {', '.join(weak)}")
    print("   Go back and review those notebooks!")

# %% [markdown]
# ---
# ## Solutions
#
# **Q1:** `I3 = np.eye(3)`
#
# **Q2:** `result = A @ B`
#
# **Q3:** `det_val = 6` (2*3 - 0*0)
#
# **Q4:** `sol = np.linalg.solve(np.array([[3,2],[1,1]]), np.array([12,5]))`
#
# **Q5:** `answer = 1` (eigenvalues = stretch factors)
#
# **Q6:** `answer = 30` (f'(x)=10x, f'(3)=30)
#
# **Q7:** `answer = 4.0` (5 - 0.1*10 = 4.0)
#
# **Q8:** `answer = 2` (chain rule)
#
# **Q9:** `answer = 2` (opposite to gradient)
#
# **Q10:** `var_val = np.var(data)`
#
# **Q11:** `answer = 2` (negative = opposite)
#
# **Q12:** `answer = 2` (normal distribution)
#
# **Q13:** `p_ab = (0.9 * 0.01) / (0.9*0.01 + 0.05*0.99)` ≈ 0.154
#
# **Q14:** `mse = np.mean((pred - actual)**2)`
#
# **Q15:** `answer = 2` (Stochastic)
#
# **Q16:** `answer = 1` (convex)
#
# **Q17:** `cos_sim = np.dot(a,b) / (np.linalg.norm(a) * np.linalg.norm(b))`
#
# **Q18:** `answer = 2` (covariance matrix)
#
# **Q19:** `answer = 2` (pure linear algebra)
#
# **Q20:** `answer = 2` (gradient)
