# %%
import numpy as np

# %%
mat1 = np.array([[1,2],[3,4]])

# %%
mat2 = np.array([[3,4],[1,2]])

# %%
print(mat1 @ mat2)
# Out:
# [[ 5  8]
#  [13 20]]

# %%
mat1.shape
# Out:
# (2, 2)

# %%
np.transpose(mat1)
# Out:
# array([[1, 3],
#        [2, 4]])

# %%
2* mat1
# Out:
# array([[2, 4],
#        [6, 8]])

# %%
mat1 + mat2
# Out:
# array([[4, 6],
#        [4, 6]])
